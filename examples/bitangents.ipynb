# %%
x, y = var('x, y')
f = 144*(x^4+y^4) - 225*(x^2+y^2) + 350*x^2*y^2 + 81
p1 = implicit_plot(f, (x,-1.5,1.5), (y,-1.5,1.5), axes=True)
#p2 = implicit_plot(x==-0.8702951154666345, (x,-1.5,1.5), (y,-1.5,1.5), axes=True,color="red")
#show(p1)
CC.<I> = ComplexField(40)
xs = [-0.87029511546663, 0.87029511546663, -0.63040747775156*I, 0.63040747775156*I, -0.72446253813449, -0.44176241447155, 0.44176241447155, 0.72446253813449]
x_plots = []
for el in xs:
    p_new = implicit_plot(x==el, (x,-1.5,1.5), (y,-1.5,1.5), axes=True, color="red")
    show(p_new)
    x_plots.append(p_new)
# Out:
# Graphics object consisting of 1 graphics primitive
# Graphics object consisting of 1 graphics primitive
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-5e2d9fa3b2ee> in <module>
#       8 x_plots = []
#       9 for el in xs:
# ---> 10     p_new = implicit_plot(x==el, (x,-RealNumber('1.5'),RealNumber('1.5')), (y,-RealNumber('1.5'),RealNumber('1.5')), axes=True, color="red")
#      11     show(p_new)
#      12     x_plots.append(p_new)
#
# /Applications/SageMath/local/lib/python3.8/site-packages/sage/misc/decorators.py in wrapper(*args, **kwds)
#     490                 options['__original_opts'] = kwds
#     491             options.update(kwds)
# --> 492             return func(*args, **options)
#     493
#     494         #Add the options specified by @options to the signature of the wrapped
#
# ...

# %%
R.<a,b,x,y> = PolynomialRing(QQ,4,order="lex")
f = 144*(x^4+y^4) - 225*(x^2+y^2) + 350*x^2*y^2 + 81
f2 = f(x=x,y=a*x*b)
print(f2)
df = f2.discriminant(x)
print(df.factor())
I = ideal([f2,df])
G = I.groebner_basis()
r = G[-1]
R1.<t> = PolynomialRing(QQ)
r = r(x=t,y=0,a=0,b=0)
print(r.factor())
#r.roots(ring=QQbar)
facts = [el[0] for el in r.factor()]
xs = []
for el in facts:
    xs += [r[0] for r in el.roots(ring=ComplexField(50))]
print(xs)
# Out:
# 144*a^4*b^4*x^4 + 350*a^2*b^2*x^4 - 225*a^2*b^2*x^2 + 144*x^4 - 225*x^2 + 81
# (17006112) * (72*a^4*b^4 + 175*a^2*b^2 + 72) * (49*a^4*b^4 - 150*a^2*b^2 + 49)^2
# (t^4 - 9/25*t^2 - 5832/19375) * (t^4 - 18/25*t^2 + 3969/38750)^4
# [-0.87029511546663, 0.87029511546663, -0.63040747775156*I, 0.63040747775156*I, -0.72446253813449, -0.44176241447155, 0.44176241447155, 0.72446253813449]
